# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib as plt

# %%
rawsurvey = pd.read_csv("survey2017.csv")
# Out:
# C:\Users\brian\anaconda3\envs\498A\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cols = rawsurvey.columns.tolist()

for i in range(len(cols)):
    print (i, cols[i])
# Out:
# 0 Job
# 1 UniqueID
# 2 Respondent_Serial
# 3 StartTime_EST
# 4 FinishTime_EST
# 5 cfmc_case_id
# 6 qLANGUAGEPREF
# 7 qgender
# 8 qage
# 9 qrace
# 10 qRACE_other6
# 11 qhispanic
# 12 qHISPANIC_other5
# 13 qeducation
# 14 qincome
# 15 qzipcmb
# 16 qSurveyZone
# 17 qBorough1
# 18 qBorough2
# 19 qBorough3
# 20 qBorough4
# 21 qBorough5
# 22 qUSETRAVELCODE01
# 23 qUSETRAVELCODE02
# 24 qUSETRAVELCODE03
# 25 qUSETRAVELCODE04
# 26 qUSETRAVELCODE05
# 27 qUSETRAVELCODE06
# 28 qUSETRAVELCODE07
# 29 qUSETRAVELCODE08
# 30 qUSETRAVELCODE09
# 31 qUSETRAVELCODE10
# 32 qUSETRAVELCODE11
# 33 qUSETRAVELCODE12
# 34 qUSETRAVELCODE13
# 35 qUSETRAVELCODE14
# 36 qUSETRAVELCODE15
# 37 qUSETRAVELCODE16
# 38 qUSETRAVELCODE17
# 39 qUSETRAVELCODE18
# 40 qUSETRAVELCODE19
# 41 qUSETRAVELCODE20
# 42 qUSETRAVELCODE21
# 43 qUSETRAVELCODE22
# 44 qUSETRAVELCODE23
# 45 qUSETRAVELCODE24
# 46 qUSETRAVELCODE25
# 47 qUSETRAVELCODE26
# 48 qlicense
# 49 qcaraccess
# 50 qCARACCESS_other4
# 51 qcarmany
# 52 qcarchange
# ...

# %%
rawsurvey["qage"]
# Out:
# Job                  float64
# UniqueID             float64
# Respondent_Serial     object
# StartTime_EST         object
# FinishTime_EST        object
#                       ...
# allwt                float64
# raceWt                object
# eduWt                 object
# agegenWt              object
# BOROUGHWt             object
# Length: 454, dtype: object

# %%
sur = rawsurvey[["qage", "qrace", "qhispanic", "qSurveyZone", "qUSETRAVELCODE21"]]

sur
# Out:
#        qage  qrace  qhispanic  qSurveyZone  qUSETRAVELCODE21
# 0      68.0    1.0        1.0          3.0               0.0
# 1     999.0    1.0        1.0          3.0               0.0
# 2      41.0    7.0        1.0          4.0               0.0
# 3      45.0    7.0        5.0          9.0               0.0
# 4      50.0    1.0        1.0          1.0               1.0
# ...     ...    ...        ...          ...               ...
# 3598   35.0    1.0        1.0          6.0               1.0
# 3599   42.0    1.0        1.0          2.0               0.0
# 3600   28.0    1.0        1.0          4.0               0.0
# 3601   30.0    6.0        5.0          9.0               0.0
# 3602    NaN    NaN        NaN          NaN               NaN
#
# [3603 rows x 5 columns]
