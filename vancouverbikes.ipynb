# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib as plt

# %%
bikeways = pd.read_csv("vancouverbikeways.csv")

# %%
bikeways
# Out:
#       Object ID Bike Route Name     Street Name          Bikeway Type Subtype  \
# 0        163348          Valley       Trafalgar          Local Street     NaN
# 1        163351        14th Ave      W 14th Ave          Local Street     NaN
# 2        163357       Alexander       Alexander          Local Street     NaN
# 3        163367  Seaside Bypass       W 2nd Ave  Protected Bike Lanes     OSB
# 4        163377   Wales Duchess         Duchess          Local Street     NaN
# ...         ...             ...             ...                   ...     ...
# 3639     166474        45th Ave      W 45th Ave          Local Street     NaN
# 3640     166475        45th Ave      W 45th Ave          Local Street     NaN
# 3641     166479        45th Ave      E 47th Ave          Local Street     NaN
# 3642     166484        29th Ave  Midlothian Ave         Painted Lanes      NB
# 3643     166486          Cambie          Cambie         Painted Lanes      NB
#
# ...
